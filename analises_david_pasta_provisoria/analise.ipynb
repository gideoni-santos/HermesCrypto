# %%
import pandas as pd

# %%
a=pd.read_csv('../data_clean/data_clean.csv')

# %%
a['Data']=pd.to_datetime(a['Data'])

# %%
a
# Out:
#          Nome Simbolo       Data     Maximo     Minimo   Abertura  Fechamento  \
# 0        Aave    AAVE 2020-10-05  55.112358  49.787900  52.675035   53.219243
# 1        Aave    AAVE 2020-10-06  53.402270  40.734578  53.291969   42.401599
# 2        Aave    AAVE 2020-10-07  42.408314  35.970690  42.399947   40.083976
# 3        Aave    AAVE 2020-10-08  44.902511  36.696057  39.885262   43.764463
# 4        Aave    AAVE 2020-10-09  47.569533  43.291776  43.764463   46.817744
# ...       ...     ...        ...        ...        ...        ...         ...
# 17693  Tether    USDT 2021-07-02   1.000830   0.999991   1.000301    1.000033
# 17694  Tether    USDT 2021-07-03   1.000674   0.999914   1.000046    0.999956
# 17695  Tether    USDT 2021-07-04   1.000165   0.998902   0.999987    0.999501
# 17696  Tether    USDT 2021-07-05   1.001040   0.999426   0.999426    1.000667
# 17697  Tether    USDT 2021-07-06   1.000879   0.999825   1.000728    1.000090
#
# ...

# %%
b=a.pivot_table(columns='Nome',index='Data',values='Fechamento',aggfunc='mean')

# %%
b[b.index>'2018-01-01']
# Out:
# Nome              Aave  Binance Coin       Bitcoin   Cardano  Crypto.com Coin  \
# Data
# 2018-01-02         NaN      8.837770  14982.099609  0.782587              NaN
# 2018-01-03         NaN      9.535880  15201.000000  1.079660              NaN
# 2018-01-04         NaN      9.213990  15599.200195  1.114120              NaN
# 2018-01-05         NaN     14.917200  17429.500000  0.999559              NaN
# 2018-01-06         NaN     22.759800  17527.000000  1.027150              NaN
# ...                ...           ...           ...       ...              ...
# 2021-07-02  233.948437    287.423094  33897.048590  1.394397         0.113914
# 2021-07-03  259.655225    298.237117  34668.548402  1.406836         0.118407
# 2021-07-04  277.038792    307.732096  35287.779766  1.458184         0.122427
# 2021-07-05  307.829079    302.377980  33746.002456  1.404898         0.115814
# 2021-07-06  316.898507    320.934802  34235.193451  1.418053         0.122856
#
# ...
